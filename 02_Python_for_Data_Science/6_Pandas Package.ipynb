# %% [markdown]
# ## 6.1: Constructing dataframes

# %%
# Load the pandas and numpy packages
import numpy as np
import pandas as pd

# %%
# Create dataframe with pandas DataFrame() constructor
dataframe = pd.DataFrame(
    data=[['abc', 3.3, 28, True], 
          ['xyz', -0.55, 0, False]],
    columns=['Label1', 'Label2', 'Label3', 'Label4'],
    index=['R0', 'R1'],
)

# %%
# Display the dataframe
dataframe
# Out:
#    Label1  Label2  Label3  Label4
# R0    abc    3.30      28    True
# R1    xyz   -0.55       0   False

# %%
# Display the dataframe's shape
dataframe.shape
# Out:
# (2, 4)

# %%
# Create an array
array = np.array(
   object=[ [ [1, 2, 3], [4, 5, 6] ], 
            [ [11, 12, 13], [14, 15, 16] ] ] )
array
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6]],
#
#        [[11, 12, 13],
#         [14, 15, 16]]])

# %%
# Returns the array's shape
array.shape
# Out:
# (2, 2, 3)

# %% [markdown]
# ## 6.2: Subsetting data.

# %%
# Load the country.csv data
country = pd.read_csv('country_subset.csv')

# %%
# Display the country dataframe
country
# Out:
#                Name Continent  Population
# 0       Afghanistan      Asia    22720000
# 1           Albania    Europe     3401200
# 2           Algeria    Africa    31471000
# 3    American Samoa   Oceania       68000
# 4           Andorra    Europe       78000
# ..              ...       ...         ...
# 234  Western Sahara    Africa      293000
# 235           Yemen      Asia    18112000
# 236      Yugoslavia    Europe    10640000
# 237          Zambia    Africa     9169000
# 238        Zimbabwe    Africa    11669000
#
# [239 rows x 3 columns]

# %%
# Select the 'Name' column
country['Name']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 234    Western Sahara
# 235             Yemen
# 236        Yugoslavia
# 237            Zambia
# 238          Zimbabwe
# Name: Name, Length: 239, dtype: object

# %%
# Put an extra bracket around the column label to return a dataframe
country[['Name']]
# Out:
#                Name
# 0       Afghanistan
# 1           Albania
# 2           Algeria
# 3    American Samoa
# 4           Andorra
# ..              ...
# 234  Western Sahara
# 235           Yemen
# 236      Yugoslavia
# 237          Zambia
# 238        Zimbabwe
#
# [239 rows x 1 columns]

# %%
type(country['Name'])
# Out:
# pandas.core.series.Series

# %%
type(country[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Select the 'Name' and 'Continent' columns
country[['Name', 'Continent']]
# Out:
#                Name Continent
# 0       Afghanistan      Asia
# 1           Albania    Europe
# 2           Algeria    Africa
# 3    American Samoa   Oceania
# 4           Andorra    Europe
# ..              ...       ...
# 234  Western Sahara    Africa
# 235           Yemen      Asia
# 236      Yugoslavia    Europe
# 237          Zambia    Africa
# 238        Zimbabwe    Africa
#
# [239 rows x 2 columns]

# %%
# Select the element in row 0 and column 1
country.iloc[1, 1]
# Out:
# 'Europe'

# %%
# Select rows 0 and 1 and column 1
country.iloc[0:238, 1]
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 233    Oceania
# 234     Africa
# 235       Asia
# 236     Europe
# 237     Africa
# Name: Continent, Length: 238, dtype: object

# %%
# Select all rows before row 7 and columns 1 thru 2
country.iloc[:7, 1:3]
# Out:
#        Continent  Population
# 0           Asia    22720000
# 1         Europe     3401200
# 2         Africa    31471000
# 3        Oceania       68000
# 4         Europe       78000
# 5         Africa    12878000
# 6  North America        8000

# %%
# Select rows 10 thru 20 and all columns from column 1 onwards
country.iloc[10:21, 1:]
# Out:
#         Continent  Population
# 10           Asia     3520000
# 11  North America      103000
# 12        Oceania    18886000
# 13         Europe     8091800
# 14           Asia     7734000
# 15  North America      307000
# 16           Asia      617000
# 17           Asia   129155000
# 18  North America      270000
# 19         Europe    10236000
# 20         Europe    10239000

# %%
# Select rows 10 thru 20 and the Continent and Population columns
country.loc[10:20, ['Continent', 'Population']]
# Out:
#         Continent  Population
# 10           Asia     3520000
# 11  North America      103000
# 12        Oceania    18886000
# 13         Europe     8091800
# 14           Asia     7734000
# 15  North America      307000
# 16           Asia      617000
# 17           Asia   129155000
# 18  North America      270000
# 19         Europe    10236000
# 20         Europe    10239000

# %% [markdown]
# ## 6.3: Subsetting data using relational operators

# %%
# Load the country.csv data
country = pd.read_csv('country.csv')

# %%
# Display the country dataframe
country
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 0          China           Asia      9572900  1277558000      133
# 1     Bangladesh           Asia       143998   129155000      897
# 2         Brazil  South America      8547403   170115000       20
# 3          India           Asia      3287263  1013662000      308
# 4         Norway         Europe       385207     5379000       14
# 5  United States  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage  Percentage
# 0       1949-10-01         Mandarin        0.81
# 1       1905-05-24          Bengali        0.98
# 2       1822-09-07       Portuguese        0.98
# 3       1905-04-30            Hindi        0.40
# 4       1905-05-17        Norwegian        0.97
# 5       1776-07-04          English        0.86

# %%
# Select rows where the Continent is South America
country[country['Continent'] == 'South America']
# Out:
#   Country      Continent  SurfaceArea  Population  Density IndependenceDate  \
# 2  Brazil  South America      8547403   170115000       20       1822-09-07
#
#   OfficialLanguage  Percentage
# 2       Portuguese        0.98

# %%
# Select rows where the Continent is not Asia
country[country['Continent'] != 'Asia']
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 2         Brazil  South America      8547403   170115000       20
# 4         Norway         Europe       385207     5379000       14
# 5  United States  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage  Percentage
# 2       1822-09-07       Portuguese        0.98
# 4       1905-05-17        Norwegian        0.97
# 5       1776-07-04          English        0.86

# %%
# Select rows where the Continent is Asia or Europe
country[(country['Continent'] == 'Asia') | (country['Continent'] == 'Europe')]
# Out:
#       Country Continent  SurfaceArea  Population  Density IndependenceDate  \
# 0       China      Asia      9572900  1277558000      133       1949-10-01
# 1  Bangladesh      Asia       143998   129155000      897       1905-05-24
# 3       India      Asia      3287263  1013662000      308       1905-04-30
# 4      Norway    Europe       385207     5379000       14       1905-05-17
#
#   OfficialLanguage  Percentage
# 0         Mandarin        0.81
# 1          Bengali        0.98
# 3            Hindi        0.40
# 4        Norwegian        0.97

# %%
# Select rows where the Continent is not in Asia
country[~(country['Continent'] == 'Asia')]
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 2         Brazil  South America      8547403   170115000       20
# 4         Norway         Europe       385207     5379000       14
# 5  United States  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage  Percentage
# 2       1822-09-07       Portuguese        0.98
# 4       1905-05-17        Norwegian        0.97
# 5       1776-07-04          English        0.86

# %% [markdown]
# ### 6.1:Challenge_Activity_Subsetting dataframes using pandas

# %% [markdown]
# ## 1:
# **This dataset contains information on taxi journeys during March 2019 in New York City. The data includes passengers, distance, fare, tip, tolls, and total.**
#
# * **Create a dataframe subset containing the total column of the cabsNY dataframe.**
#
# **The code contains all imports, loads the dataset, and prints the total column.**

# %%
# Loads necessary packages
import pandas as pd

# Loads the taxi.csv dataset
taxicabsNY = pd.read_csv('taxi.csv')

# Subset a column of the taxicabsNY dataframe by specifying the column name
total = taxicabsNY[['total']] # Your code goes here

# Prints the column
print(total)
# Out:
#     total
# 0   16.30
# 1   12.80
# 2   42.06
# 3   36.80
# 4   13.56
# 5   14.75
# 6    9.80
# 7   20.15
# 8   14.80
# 9   13.80
# 10  20.16
# 11  26.16
# 12   8.30
# 13  73.26
# 14  10.55
# 15  11.80
# 16  11.76
# 17  12.96
# 18  14.30
# 19  17.80
# 20  21.96
# 21  20.16
# 22  36.30
# 23  26.16
# 24  60.06
# 25  18.69
# 26   8.97
# 27  10.56
# 28   8.30
# 29   7.80
# 30  58.87
# 31  80.80
# 32  12.42
# 33  15.30
# 34  14.80
# 35  17.76
# 36  23.50
# 37  20.15
# 38  13.30
# 39  10.56
# 40  12.96
# 41  21.36
# 42  21.36
# 43  15.80
# 44  12.35
# 45  11.30
# 46   8.30
# 47  11.62
# 48  10.30
# 49   7.56

# %% [markdown]
# ## 2:
#
# **This dataset contains information on taxi journeys during March 2019 in New York City. The data includes pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, and dropoff_borough.**
#
# * **Using the iloc() method, display the first 13 columns and the first 12 rows of the cabsNY dataframe.**
#
# **The code contains all imports, loads the dataset, and prints the column.**

# %%
# Loads necessary packages
import pandas as pd

# Loads the taxi.csv dataset
cabsNY = pd.read_csv('taxi.csv')

# Subset cabsNY using the iloc method
df = cabsNY.iloc[:12 , :]# Your code goes here

# Prints the column
print(df)
# Out:
#     passengers  distance  fare   tip  tolls  total
# 0            1      1.90  11.5  1.00   0.00  16.30
# 1            1      1.15   7.5  1.00   0.00  12.80
# 2            1      8.84  32.0  0.00   5.76  42.06
# 3            1      6.34  27.5  6.00   0.00  36.80
# 4            5      0.95   7.5  2.26   0.00  13.56
# 5            0      1.60   8.5  2.95   0.00  14.75
# 6            1      0.70   5.5  0.00   0.00   9.80
# 7            1      3.00  13.0  3.35   0.00  20.15
# 8            1      2.20  11.0  0.00   0.00  14.80
# 9            1      0.97  10.5  0.00   0.00  13.80
# 10           4      1.46  13.5  3.36   0.00  20.16
# 11           2      4.11  18.0  4.36   0.00  26.16

# %% [markdown]
# ## 3:
#
# **This dataset contains information on taxi journeys during March 2019 in New York City. The data includes passengers, distance, fare, tip, tolls, and total.**
#
# * **Using the loc() method, display all rows after and including row 5, and the total column of the cabsNY dataframe.**
#
# **The code contains all imports, loads the dataset, and prints the column.**

# %%
# Subset cabsNY by specifying columns and rows using the loc method
df = cabsNY.loc[5:, ['total']] # Your code goes here

# Prints the column
print(df)
# Out:
#     total
# 5   14.75
# 6    9.80
# 7   20.15
# 8   14.80
# 9   13.80
# 10  20.16
# 11  26.16
# 12   8.30
# 13  73.26
# 14  10.55
# 15  11.80
# 16  11.76
# 17  12.96
# 18  14.30
# 19  17.80
# 20  21.96
# 21  20.16
# 22  36.30
# 23  26.16
# 24  60.06
# 25  18.69
# 26   8.97
# 27  10.56
# 28   8.30
# 29   7.80
# 30  58.87
# 31  80.80
# 32  12.42
# 33  15.30
# 34  14.80
# 35  17.76
# 36  23.50
# 37  20.15
# 38  13.30
# 39  10.56
# 40  12.96
# 41  21.36
# 42  21.36
# 43  15.80
# 44  12.35
# 45  11.30
# 46   8.30
# 47  11.62
# 48  10.30
# 49   7.56

# %% [markdown]
# ## 4:
#
# **This dataset contains information on taxi journeys during March 2019 in New York City. The data includes passengers, distance, fare, tip, tolls, and total.**
#
# * **Display all rows of the taxicabsNY dataframe where the tolls column is >= 9.**
#
# **The code contains all imports, loads the dataset, and prints the column.**

# %%
# Subset taxicabsNY using comparison operators
df = taxicabsNY[taxicabsNY['tolls'] >= 9] # Your code goes here

# Prints the column
print(df)
# Out:
# Empty DataFrame
# Columns: [passengers, distance, fare, tip, tolls, total]
# Index: []

# %% [markdown]
# ## 5:
#
# **This dataset contains information on taxi journeys during March 2019 in New York City. The data includes pickup, dropoff, pickup_zone, dropoff_zone, pickup_borough, and dropoff_borough.**
#
# * **Display all rows of the taxisNY dataframe where dropoff_borough is at Queens and pickup_zone is either at Prospect-Lefferts Gardens or Sunnyside.**
#
# **The code contains all imports, loads the dataset, and prints the column.**

# %%
# Loads necessary packages
import pandas as pd

# Loads the taxi.csv dataset
taxisNY = pd.read_csv('taxi.csv')

# Subset taxisNY using comparison and logical operators
df = taxisNY[(taxisNY['total'] > 10) & (taxisNY['tolls'] < 5)] # Your code goes here

# Prints the column
print(df)
# Out:
#     passengers  distance  fare   tip  tolls  total
# 0            1      1.90  11.5  1.00    0.0  16.30
# 1            1      1.15   7.5  1.00    0.0  12.80
# 3            1      6.34  27.5  6.00    0.0  36.80
# 4            5      0.95   7.5  2.26    0.0  13.56
# 5            0      1.60   8.5  2.95    0.0  14.75
# 7            1      3.00  13.0  3.35    0.0  20.15
# 8            1      2.20  11.0  0.00    0.0  14.80
# 9            1      0.97  10.5  0.00    0.0  13.80
# 10           4      1.46  13.5  3.36    0.0  20.16
# 11           2      4.11  18.0  4.36    0.0  26.16
# 14           2      0.40   5.5  1.75    0.0  10.55
# 15           1      1.00   7.0  1.50    0.0  11.80
# 16           1      0.97   6.0  1.96    0.0  11.76
# 17           1      1.38   7.0  2.16    0.0  12.96
# 18           1      1.48  11.0  0.00    0.0  14.30
# 19           4      1.50  11.5  2.00    0.0  17.80
# 20           2      3.26  15.0  3.66    0.0  21.96
# 21           2      2.36  12.5  3.36    0.0  20.16
# 22           2     11.20  35.5  0.00    0.0  36.30
# 23           2      5.24  18.0  4.36    0.0  26.16
# 25           4      3.33  14.0  0.89    0.0  18.69
# 27           2      1.04   5.5  1.76    0.0  10.56
# 31           1     21.30  79.5  0.00    0.0  80.80
# 32           1      1.10   7.5  1.62    0.0  12.42
# 33           1      1.95  12.0  0.00    0.0  15.30
# 34           1      1.90  11.5  0.00    0.0  14.80
# 35           1      1.78  10.5  2.96    0.0  17.76
# 36           1      3.10  14.5  4.70    0.0  23.50
# 37           1      2.70  13.5  3.35    0.0  20.15
# 38           1      2.10   9.0  0.00    0.0  13.30
# 39           1      0.97   5.5  1.76    0.0  10.56
# 40           1      1.47   7.5  2.16    0.0  12.96
# 41           1      2.50  14.5  3.56    0.0  21.36
# 42           3      3.77  14.5  3.56    0.0  21.36
# 43           1      1.30  12.5  0.00    0.0  15.80
# 44           2      1.20   6.0  2.05    0.0  12.35
# 45           1      1.10   6.0  1.50    0.0  11.30
# 47           1      0.60   5.0  2.32    0.0  11.62
# 48           1      1.54   9.5  0.00    0.0  10.30

# %% [markdown]
# ## 6.4: Dataframe methods in pandas.

# %%
# Load the country.csv data
country = pd.read_csv('country.csv')

# %%
# Display the country dataframe
country
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 0          China           Asia      9572900  1277558000      133
# 1     Bangladesh           Asia       143998   129155000      897
# 2         Brazil  South America      8547403   170115000       20
# 3          India           Asia      3287263  1013662000      308
# 4         Norway         Europe       385207     5379000       14
# 5  United States  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage  Percentage
# 0       1949-10-01         Mandarin        0.81
# 1       1905-05-24          Bengali        0.98
# 2       1822-09-07       Portuguese        0.98
# 3       1905-04-30            Hindi        0.40
# 4       1905-05-17        Norwegian        0.97
# 5       1776-07-04          English        0.86

# %%
# Return the value in row 0 of the Continent column
country.at[0, 'Continent']
# Out:
# 'Asia'

# %%
# Use drop() to remove the Percentage column
country.drop(labels='Percentage', axis=1)
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 0          China           Asia      9572900  1277558000      133
# 1     Bangladesh           Asia       143998   129155000      897
# 2         Brazil  South America      8547403   170115000       20
# 3          India           Asia      3287263  1013662000      308
# 4         Norway         Europe       385207     5379000       14
# 5  United States  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage
# 0       1949-10-01         Mandarin
# 1       1905-05-24          Bengali
# 2       1822-09-07       Portuguese
# 3       1905-04-30            Hindi
# 4       1905-05-17        Norwegian
# 5       1776-07-04          English

# %%
help(country.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
#         Alternative to specifying axis (``labels, axis=0``
#         is equivalent to ``index=labels``).
#     columns : single label or list-like
#         Alternative to specifying axis (``labels, axis=1``
#         is equivalent to ``columns=labels``).
#     level : int or level name, optional
#         For MultiIndex, level from which the labels will be removed.
#     inplace : bool, default False
#         If False, return a copy. Otherwise, do operation
#         in place and return None.
#     errors : {'ignore', 'raise'}, default 'raise'
#         If 'ignore', suppress error and only existing labels are
#         dropped.
#
#     Returns
#     -------
#     DataFrame or None
#         Returns DataFrame or None DataFrame with the specified
#         index or column labels removed or None if inplace=True.
#
#     Raises
#     ------
#     KeyError
#         If any of the labels is not found in the selected axis.
#
#     See Also
#     --------
#     DataFrame.loc : Label-location based indexer for selection by label.
#     DataFrame.dropna : Return DataFrame with labels on given axis omitted
#         where (all or any) data are missing.
#     DataFrame.drop_duplicates : Return DataFrame with duplicate rows
#         removed, optionally only considering certain columns.
#     Series.drop : Return Series with specified index labels removed.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame(np.arange(12).reshape(3, 4),
#     ...                   columns=['A', 'B', 'C', 'D'])
#     >>> df
#        A  B   C   D
#     0  0  1   2   3
#     1  4  5   6   7
#     2  8  9  10  11
#
#     Drop columns
#
#     >>> df.drop(['B', 'C'], axis=1)
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     >>> df.drop(columns=['B', 'C'])
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     Drop a row by index
#
#     >>> df.drop([0, 1])
#        A  B   C   D
#     2  8  9  10  11
#
#     Drop columns and/or rows of MultiIndex DataFrame
#
#     >>> midx = pd.MultiIndex(levels=[['llama', 'cow', 'falcon'],
#     ...                              ['speed', 'weight', 'length']],
#     ...                      codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
#     ...                             [0, 1, 2, 0, 1, 2, 0, 1, 2]])
#     >>> df = pd.DataFrame(index=midx, columns=['big', 'small'],
#     ...                   data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
#     ...                         [250, 150], [1.5, 0.8], [320, 250],
#     ...                         [1, 0.8], [0.3, 0.2]])
#     >>> df
#                     big     small
#     llama   speed   45.0    30.0
#             weight  200.0   100.0
#             length  1.5     1.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#             length  1.5     0.8
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8
#             length  0.3     0.2
#
#     Drop a specific index combination from the MultiIndex
#     DataFrame, i.e., drop the combination ``'falcon'`` and
#     ``'weight'``, which deletes only the corresponding row
#
#     >>> df.drop(index=('falcon', 'weight'))
#                     big     small
#     llama   speed   45.0    30.0
#             weight  200.0   100.0
#             length  1.5     1.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#             length  1.5     0.8
#     falcon  speed   320.0   250.0
#             length  0.3     0.2
#
#     >>> df.drop(index='cow', columns='small')
#                     big
#     llama   speed   45.0
#             weight  200.0
#             length  1.5
#     falcon  speed   320.0
#             weight  1.0
#             length  0.3
#
#     >>> df.drop(index='length', level=1)
#                     big     small
#     llama   speed   45.0    30.0
#             weight  200.0   100.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8

# %%
# Use insert() to add a new column
percent = [81, 98, 98, 40, 97, 86]
country.insert(loc=7, column='Percent', value=percent)
country
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 0          China           Asia      9572900  1277558000      133
# 1     Bangladesh           Asia       143998   129155000      897
# 2         Brazil  South America      8547403   170115000       20
# 3          India           Asia      3287263  1013662000      308
# 4         Norway         Europe       385207     5379000       14
# 5  United States  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage  Percent  Percentage
# 0       1949-10-01         Mandarin       81        0.81
# 1       1905-05-24          Bengali       98        0.98
# 2       1822-09-07       Portuguese       98        0.98
# 3       1905-04-30            Hindi       40        0.40
# 4       1905-05-17        Norwegian       97        0.97
# 5       1776-07-04          English       86        0.86

# %%
# Use replace to change the country label
country.replace(to_replace='United States', value='USA')
# Out:
#       Country      Continent  SurfaceArea  Population  Density  \
# 0       China           Asia      9572900  1277558000      133
# 1  Bangladesh           Asia       143998   129155000      897
# 2      Brazil  South America      8547403   170115000       20
# 3       India           Asia      3287263  1013662000      308
# 4      Norway         Europe       385207     5379000       14
# 5         USA  North America      9363520   278357000       30
#
#   IndependenceDate OfficialLanguage  Percent  Percentage
# 0       1949-10-01         Mandarin       81        0.81
# 1       1905-05-24          Bengali       98        0.98
# 2       1822-09-07       Portuguese       98        0.98
# 3       1905-04-30            Hindi       40        0.40
# 4       1905-05-17        Norwegian       97        0.97
# 5       1776-07-04          English       86        0.86

# %%
# Use sort_values to arrange by density
country.sort_values(by='Density')
# Out:
#          Country      Continent  SurfaceArea  Population  Density  \
# 4         Norway         Europe       385207     5379000       14
# 2         Brazil  South America      8547403   170115000       20
# 5  United States  North America      9363520   278357000       30
# 0          China           Asia      9572900  1277558000      133
# 3          India           Asia      3287263  1013662000      308
# 1     Bangladesh           Asia       143998   129155000      897
#
#   IndependenceDate OfficialLanguage  Percent  Percentage
# 4       1905-05-17        Norwegian       97        0.97
# 2       1822-09-07       Portuguese       98        0.98
# 5       1776-07-04          English       86        0.86
# 0       1949-10-01         Mandarin       81        0.81
# 3       1905-04-30            Hindi       40        0.40
# 1       1905-05-24          Bengali       98        0.98
