# %% [markdown]
# ## Try 3.2.1: Descriptive statistics in Python.

# %% [markdown]
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Modify the code to create a histogram and calculate descriptive statistics for the Length feature. The Length feature is the length, in centimeters, measured lying down for respondents aged 0-3.**

# %%
# Import pandas and matplotlib packages
import pandas as pd
import matplotlib.pyplot as plt  # used to create a histogram

# %%
# Load the dataset
nhanes = pd.read_csv('nhanes.csv')

# View dataset (first/last 5 rows and the first/last 10 columns)
nhanes
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths    Race1    Race3  \
# 0     51624  2009_10    male   34     30-39      409.0    White      NaN
# 1     51624  2009_10    male   34     30-39      409.0    White      NaN
# 2     51624  2009_10    male   34     30-39      409.0    White      NaN
# 3     51625  2009_10    male    4       0-9       49.0    Other      NaN
# 4     51630  2009_10  female   49     40-49      596.0    White      NaN
# ...     ...      ...     ...  ...       ...        ...      ...      ...
# 9995  71909  2011_12    male   28     20-29        NaN  Mexican  Mexican
# 9996  71910  2011_12  female    0       0-9        5.0    White    White
# 9997  71911  2011_12    male   27     20-29        NaN  Mexican  Mexican
# 9998  71915  2011_12    male   60     60-69        NaN    White    White
# 9999  71915  2011_12    male   60     60-69        NaN    White    White
#
#            Education MaritalStatus  ... RegularMarij  AgeRegMarij  HardDrugs  \
# ...

# %%
# Calculate a selection of descriptive statistics for all numeric
# features with describe()

## 45 numeric features in the dataset so not all can be shown
nhanes.describe()
# Out:
#                 ID           Age    AgeMonths    HHIncomeMid      Poverty  \
# count  10000.00000  10000.000000  4962.000000    9189.000000  9274.000000
# mean   61944.64380     36.742100   420.123942   57206.170421     2.801844
# std     5871.16716     22.397566   259.043091   33020.276584     1.677909
# min    51624.00000      0.000000     0.000000    2500.000000     0.000000
# 25%    56904.50000     17.000000   199.000000   30000.000000     1.240000
# 50%    62159.50000     36.000000   418.000000   50000.000000     2.700000
# 75%    67039.00000     54.000000   624.000000   87500.000000     4.710000
# max    71915.00000     80.000000   959.000000  100000.000000     5.000000
#
#          HomeRooms       Weight      Length   HeadCirc       Height  ...  \
# count  9931.000000  9922.000000  543.000000  88.000000  9647.000000  ...
# mean      6.248918    70.981798   85.016022  41.180682   161.877838  ...
# std       2.277538    29.125357   13.705026   2.311483    20.186567  ...
# ...

# %%
# Calculate the mean for a subset of numeric features in the dataframe

## Specifying axis=0 returns the mean of each feature (column),
## if axis=1, the mean of each instance (row) would be returned.
nhanes[['Age', 'AgeMonths']].mean(axis=0, skipna=True)
# Out:
# Age           36.742100
# AgeMonths    420.123942
# dtype: float64

# %% [markdown]
# ### Examine the Pulse feature

# %%
# Visualize Pulse feature with a histogram
plt.hist(x=nhanes['Pulse'])
plt.show()

# %%
# Calculate a selection of descriptive statistics for a single feature
# with describe()
nhanes['Pulse'].describe()
# Out:
# count    8563.000000
# mean       73.559734
# std        12.155422
# min        40.000000
# 25%        64.000000
# 50%        72.000000
# 75%        82.000000
# max       136.000000
# Name: Pulse, dtype: float64

# %%
# Calculate the Pulse features' variance
nhanes['Pulse'].var()
# Out:
# np.float64(147.75428593703842)

# %%
# Calculate the Pulse features' skewness
nhanes['Pulse'].skew()
# Out:
# np.float64(0.4540567386432881)

# %%
# Calculate the Pulse features' kurtosis
nhanes['Pulse'].kurtosis()
# Out:
# np.float64(0.46019620590236787)

# %% [markdown]
# ## CHALLENGE ACTIVITY| 3.2.2: Descriptive statistics using pandas

# %% [markdown]
# ## 1: This dataset contains a summary of real estate listings for 20 different cities in Texas during June 2015.
#
# * **Using a descriptive statistics method, calculate the mean number of homes sold ("sales") over all cities.**
#
# ## The code contains all imports, loads the dataset, and prints the mean.

# %%
# Import packages and functions
import pandas as pd

housing = pd.read_csv('txhousing.csv')

meanHomes = housing['sales'].mean()

print('Mean:', meanHomes)
# Out:
# Mean: 433.72727272727275

# %% [markdown]
# # 2:This dataset contains a summary of real estate listings for 20 different cities in Texas during June 2015.
#
# * **Using a descriptive statistics method, calculate the maximum number of homes sold ("sales") over all cities.**
#
# ## The code contains all imports, loads the dataset, and prints the maximum.

# %%
maxHomes = housing['sales'].max()

print('Maximum sales for homes sold over all cities:', maxHomes)
# Out:
# Maximum sales for homes sold over all cities: 1789

# %% [markdown]
# # 3. This dataset contains a summary of real estate listings for 20 different cities in Texas during June 2015.
#
# * **Using a descriptive statistics method, generate a table of descriptive statistics for the volume of homes sold ("volume") over all cities.**
# ## The code contains all imports, loads the dataset, and prints the table.

# %%
table = housing[['city','volume']]

print(table)
# Out:
#                   city     volume
# 0                Paris    6238350
# 1    Killeen-Fort Hood   41102980
# 2        Collin County  614959441
# 3             Amarillo   61748196
# 4              Lubbock   72529370
# 5             Beaumont   48007961
# 6            Fort Bend  429731131
# 7              El Paso  118116401
# 8           San Angelo   31155867
# 9          Port Arthur   10864768
# 10     Sherman-Denison   25104282
# 11               Tyler   82254422
# 12           Texarkana   22132772
# 13             Midland   63667557
# 14              Laredo   18468901
# 15          Fort Worth  248314498
# 16       Denton County  306978637
# 17  South Padre Island    8665950
# 18       Temple-Belton   35933886
# 19              Odessa   20320574
# 20              Lufkin   12051050
# 21              Irving   46433702
